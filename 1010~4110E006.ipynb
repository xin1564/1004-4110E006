# %%
x = 121654
y = 2.2154
z = 121j

print(type(x))
print(type(y))
print(type(z))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'complex'>

# %%
x = 1.0E
y = 1.0E1
a = 1.0E12
z = -54.35

print(type(x))
print(type(y))
print(type(z))
# Out:
#   File "<ipython-input-14-70120e4d8e22>", line 1
#     x = 1.0E
#            ^
# SyntaxError: invalid syntax

# %%
x = float(1+210)

y = int(2.32)

z = complex(1.10)

print(x)
print(y)
print(z)

print(type(x))
print(type(y))
print(type(z))

# %%
import random

print(random.randrange(10, 100))
# Out:
# 62

# %%
a = "Hello, World!"
print(a[0])
print(a[2])
print(a[5])
print(a[7])
print(a[11])
# Out:
# H
# l
# ,
# W
# d

# %%
a = "hi,fsdgjsfdgg"
print(len(a))
# Out:
# 13

# %%
quantity = 3
itemno = 567
price = 49.95
myorder = "I want to pay {1} dollars for {0} pieces of item {2}."
print(myorder.format(quantity, itemno, price))

# %%
txt = "We are the so-called "KOALA" from the north."
print(txt)
# Out:
#   File "<ipython-input-20-05aa57f4f2f9>", line 1
#     txt = "We are the so-called "KOALA" from the north."
#                                      ^
# SyntaxError: invalid syntax

# %%
txt = "We are the so-called \"KOALA\" from the north."
print(txt)
# Out:
# We are the so-called "KOALA" from the north.

# %%
thislist = ["ab", "cd", "ef", "gh", "ij"]

print(thislist)
# Out:
# ['ab', 'cd', 'ef', 'gh', 'ij']

# %%
thislist = list(("apple", "banana", "banana"))
print(thislist)
# Out:
# ['apple', 'banana', 'banana']

# %%
thislist = set(("apple", "banana", "banana"))
print(thislist)
# Out:
# {'banana', 'apple'}

# %%
thislist = ["apple", "banana", "cherry"]
thislist[1] = "這個取代第二個取代"

print(thislist)
# Out:
# ['apple', '這個取代第二個取代', 'cherry']

# %%
thislist = ["ab", "cd", "ef"]

thislist.insert(2, "塞指定數後面")

print(thislist)
# Out:
# ['ab', 'cd', '塞指定數後面', 'ef']

# %%
thisdict =	{
  "apple": "Food",
  "coconut": "fruit",
  "Lei": 2003
}
print(thisdict)
# Out:
# {'apple': 'Food', 'coconut': 'fruit', 'Lei': 2003}

# %%
thisdict =	{
  "apple": "Food",
  "coconut": "fruit",
  "Lei": 20023,
  "Lei": 2003
}
print(thisdict)
# Out:
# {'apple': 'Food', 'coconut': 'fruit', 'Lei': 2003}

# %%
thisdict =	{
  "apple": "Food",
  "coconut": "fruit",
  
  "Lei": 2003
}

thisdict["Lei"] = 6530

print(thisdict)
# Out:
# {'apple': 'Food', 'coconut': 'fruit', 'Lei': 6530}

# %%
thisdict =	{
  "apple": "Food",
  "coconut": "fruit",
  "Lei": 2003
}

thisdict["SFSD"] = 6530

print(thisdict)
# Out:
# {'apple': 'Food', 'coconut': 'fruit', 'Lei': 2003, 'SFSD': 6530}

# %%
thisdict =	{
  "apple": "Food",
  "coconut": "fruit",
  "Lei": 2003
}

thisdict.pop("Lei")

print(thisdict)
# Out:
# {'apple': 'Food', 'coconut': 'fruit'}

# %%
thisdict =	{
  "apple": "Food",
  "coconut": "fruit",
  "Lei": 2003
}
for x in thisdict:
  print(x)
# Out:
# apple
# coconut
# Lei
